# %% [markdown]
# # N-grams
# So far we’ve considered words as individual units, and considered their relationships with sentiment or frequency of occurrence. However, many interesting text analyses are based on the relationships between words.
# One such relationship is given by n-grams.
#
# N-grams are groups of n consecutive words that appear in a given text corpus.
#
# Bigrams are groups of 2 consecutive words (e.g. she went, he ate, car crashed)
#
# Trigrams are groups of 3 consecutive words (e.g. she went home, he ate a, the car crashed).

# %%
# %pip install gutenbergpy tidytext
# Out:
# Requirement already satisfied: gutenbergpy in c:\python310\lib\site-packages (0.3.4)
# Requirement already satisfied: tidytext in c:\python310\lib\site-packages (0.0.1)
# Requirement already satisfied: lxml>=3.2.0 in c:\python310\lib\site-packages (from gutenbergpy) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in c:\python310\lib\site-packages (from gutenbergpy) (57.4.0)
# Requirement already satisfied: httpsproxy-urllib2 in c:\python310\lib\site-packages (from gutenbergpy) (1.0)
# Requirement already satisfied: chardet in c:\python310\lib\site-packages (from gutenbergpy) (4.0.0)
# Requirement already satisfied: future>=0.15.2 in c:\python310\lib\site-packages (from gutenbergpy) (0.18.2)
# Requirement already satisfied: pymongo in c:\python310\lib\site-packages (from gutenbergpy) (4.0.2)
# Requirement already satisfied: siuba in c:\python310\lib\site-packages (from tidytext) (0.1.2)
# Requirement already satisfied: pandas>=0.24.0 in c:\python310\lib\site-packages (from siuba->tidytext) (1.4.0)
# Requirement already satisfied: numpy>=1.12.0 in c:\python310\lib\site-packages (from siuba->tidytext) (1.21.4)
# Requirement already satisfied: SQLAlchemy>=1.2.19 in c:\python310\lib\site-packages (from siuba->tidytext) (1.4.32)
# Requirement already satisfied: PyYAML>=3.0.0 in c:\python310\lib\site-packages (from siuba->tidytext) (6.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\python310\lib\site-packages (from pandas>=0.24.0->siuba->tidytext) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas>=0.24.0->siuba->tidytext) (2021.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\python310\lib\site-packages (from SQLAlchemy>=1.2.19->siuba->tidytext) (1.1.2)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->siuba->tidytext) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import gutenbergpy.textget
from tidytext import unnest_tokens
import nltk
nltk.download('punkt')

raw_book = gutenbergpy.textget.get_text_by_id(161)
sense_sensibility_text = gutenbergpy.textget.strip_headers(raw_book).decode("utf-8")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\bogda\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # E1 - Warm up
# Write pure python code to get all the bigrams from Sense and Sensibility as a list of tuples.
#
# Don't use any tidytext or nltk functionality.

# %%
# Write your code below
sense_sensibility_words = sense_sensibility_text.split()
sense_sensibility_bigrams = [(word1, word2) for word1, word2 in zip(sense_sensibility_words, sense_sensibility_words[1:])]
sense_sensibility_bigrams
# Out:
# [('[Illustration]', 'Sense'),
#  ('Sense', 'and'),
#  ('and', 'Sensibility'),
#  ('Sensibility', 'by'),
#  ('by', 'Jane'),
#  ('Jane', 'Austen'),
#  ('Austen', '(1811)'),
#  ('(1811)', 'Contents'),
#  ('Contents', 'CHAPTER'),
#  ('CHAPTER', 'I'),
#  ('I', 'CHAPTER'),
#  ('CHAPTER', 'II'),
#  ('II', 'CHAPTER'),
#  ('CHAPTER', 'III'),
#  ('III', 'CHAPTER'),
#  ('CHAPTER', 'IV'),
#  ('IV', 'CHAPTER'),
#  ('CHAPTER', 'V'),
#  ('V', 'CHAPTER'),
#  ('CHAPTER', 'VI'),
#  ('VI', 'CHAPTER'),
#  ('CHAPTER', 'VII'),
#  ('VII', 'CHAPTER'),
#  ('CHAPTER', 'VIII'),
#  ('VIII', 'CHAPTER'),
#  ('CHAPTER', 'IX'),
#  ('IX', 'CHAPTER'),
#  ('CHAPTER', 'X'),
#  ('X', 'CHAPTER'),
#  ('CHAPTER', 'XI'),
#  ('XI', 'CHAPTER'),
#  ('CHAPTER', 'XII'),
#  ('XII', 'CHAPTER'),
#  ('CHAPTER', 'XIII'),
#  ('XIII', 'CHAPTER'),
#  ('CHAPTER', 'XIV'),
#  ('XIV', 'CHAPTER'),
#  ('CHAPTER', 'XV'),
#  ('XV', 'CHAPTER'),
#  ('CHAPTER', 'XVI'),
#  ('XVI', 'CHAPTER'),
#  ('CHAPTER', 'XVII'),
#  ('XVII', 'CHAPTER'),
#  ('CHAPTER', 'XVIII'),
#  ('XVIII', 'CHAPTER'),
#  ('CHAPTER', 'XIX'),
#  ('XIX', 'CHAPTER'),
#  ('CHAPTER', 'XX'),
#  ('XX', 'CHAPTER'),
#  ('CHAPTER', 'XXI'),
#  ('XXI', 'CHAPTER'),
#  ('CHAPTER', 'XXII'),
#  ('XXII', 'CHAPTER'),
#  ('CHAPTER', 'XXIII'),
#  ('XXIII', 'CHAPTER'),
#  ('CHAPTER', 'XXIV'),
#  ('XXIV', 'CHAPTER'),
#  ('CHAPTER', 'XXV'),
#  ('XXV', 'CHAPTER'),
#  ('CHAPTER', 'XXVI'),
#  ('XXVI', 'CHAPTER'),
#  ('CHAPTER', 'XXVII'),
#  ('XXVII', 'CHAPTER'),
#  ('CHAPTER', 'XXVIII'),
#  ('XXVIII', 'CHAPTER'),
#  ('CHAPTER', 'XXIX'),
#  ('XXIX', 'CHAPTER'),
#  ('CHAPTER', 'XXX'),
#  ('XXX', 'CHAPTER'),
#  ('CHAPTER', 'XXXI'),
#  ('XXXI', 'CHAPTER'),
#  ('CHAPTER', 'XXXII'),
#  ('XXXII', 'CHAPTER'),
#  ('CHAPTER', 'XXXIII'),
#  ('XXXIII', 'CHAPTER'),
#  ('CHAPTER', 'XXXIV'),
#  ('XXXIV', 'CHAPTER'),
#  ('CHAPTER', 'XXXV'),
#  ('XXXV', 'CHAPTER'),
#  ('CHAPTER', 'XXXVI'),
#  ('XXXVI', 'CHAPTER'),
#  ('CHAPTER', 'XXXVII'),
#  ('XXXVII', 'CHAPTER'),
#  ('CHAPTER', 'XXXVIII'),
#  ('XXXVIII', 'CHAPTER'),
#  ('CHAPTER', 'XXXIX'),
#  ('XXXIX', 'CHAPTER'),
#  ('CHAPTER', 'XL'),
#  ('XL', 'CHAPTER'),
#  ('CHAPTER', 'XLI'),
#  ('XLI', 'CHAPTER'),
#  ('CHAPTER', 'XLII'),
#  ('XLII', 'CHAPTER'),
#  ('CHAPTER', 'XLIII'),
#  ('XLIII', 'CHAPTER'),
#  ('CHAPTER', 'XLIV'),
#  ('XLIV', 'CHAPTER'),
#  ('CHAPTER', 'XLV'),
#  ('XLV', 'CHAPTER'),
#  ('CHAPTER', 'XLVI'),
#  ('XLVI', 'CHAPTER'),
#  ('CHAPTER', 'XLVII'),
#  ('XLVII', 'CHAPTER'),
#  ('CHAPTER', 'XLVIII'),
#  ('XLVIII', 'CHAPTER'),
#  ('CHAPTER', 'XLIX'),
#  ('XLIX', 'CHAPTER'),
#  ('CHAPTER', 'L'),
#  ('L', 'CHAPTER'),
#  ('CHAPTER', 'I.'),
#  ('I.', 'The'),
#  ('The', 'family'),
#  ('family', 'of'),
#  ('of', 'Dashwood'),
#  ('Dashwood', 'had'),
#  ('had', 'long'),
#  ('long', 'been'),
#  ('been', 'settled'),
#  ('settled', 'in'),
#  ('in', 'Sussex.'),
#  ('Sussex.', 'Their'),
#  ('Their', 'estate'),
#  ('estate', 'was'),
#  ('was', 'large,'),
#  ('large,', 'and'),
#  ('and', 'their'),
#  ('their', 'residence'),
#  ('residence', 'was'),
#  ('was', 'at'),
#  ('at', 'Norland'),
#  ('Norland', 'Park,'),
#  ('Park,', 'in'),
#  ('in', 'the'),
#  ('the', 'centre'),
#  ('centre', 'of'),
#  ('of', 'their'),
#  ('their', 'property,'),
#  ('property,', 'where,'),
#  ('where,', 'for'),
#  ('for', 'many'),
#  ('many', 'generations,'),
#  ('generations,', 'they'),
#  ('they', 'had'),
#  ('had', 'lived'),
#  ('lived', 'in'),
#  ('in', 'so'),
#  ('so', 'respectable'),
#  ('respectable', 'a'),
#  ('a', 'manner'),
#  ('manner', 'as'),
#  ('as', 'to'),
#  ('to', 'engage'),
#  ('engage', 'the'),
#  ('the', 'general'),
#  ('general', 'good'),
#  ('good', 'opinion'),
#  ('opinion', 'of'),
#  ('of', 'their'),
#  ('their', 'surrounding'),
#  ('surrounding', 'acquaintance.'),
#  ('acquaintance.', 'The'),
#  ('The', 'late'),
#  ('late', 'owner'),
#  ('owner', 'of'),
#  ('of', 'this'),
#  ('this', 'estate'),
#  ('estate', 'was'),
#  ('was', 'a'),
#  ('a', 'single'),
#  ('single', 'man,'),
#  ('man,', 'who'),
#  ('who', 'lived'),
#  ('lived', 'to'),
#  ('to', 'a'),
#  ('a', 'very'),
#  ('very', 'advanced'),
#  ('advanced', 'age,'),
#  ('age,', 'and'),
#  ('and', 'who'),
#  ('who', 'for'),
#  ('for', 'many'),
#  ('many', 'years'),
#  ('years', 'of'),
#  ('of', 'his'),
#  ('his', 'life,'),
#  ('life,', 'had'),
#  ('had', 'a'),
#  ('a', 'constant'),
#  ('constant', 'companion'),
#  ('companion', 'and'),
#  ('and', 'housekeeper'),
#  ('housekeeper', 'in'),
#  ('in', 'his'),
#  ('his', 'sister.'),
#  ('sister.', 'But'),
#  ('But', 'her'),
#  ('her', 'death,'),
#  ('death,', 'which'),
#  ('which', 'happened'),
#  ('happened', 'ten'),
#  ('ten', 'years'),
#  ('years', 'before'),
#  ('before', 'his'),
#  ('his', 'own,'),
#  ('own,', 'produced'),
#  ('produced', 'a'),
#  ('a', 'great'),
#  ('great', 'alteration'),
#  ('alteration', 'in'),
#  ('in', 'his'),
#  ('his', 'home;'),
#  ('home;', 'for'),
#  ('for', 'to'),
#  ('to', 'supply'),
#  ('supply', 'her'),
#  ('her', 'loss,'),
#  ('loss,', 'he'),
#  ('he', 'invited'),
#  ('invited', 'and'),
#  ('and', 'received'),
#  ('received', 'into'),
#  ('into', 'his'),
#  ('his', 'house'),
#  ('house', 'the'),
#  ('the', 'family'),
#  ('family', 'of'),
#  ('of', 'his'),
#  ('his', 'nephew'),
#  ('nephew', 'Mr.'),
#  ('Mr.', 'Henry'),
#  ('Henry', 'Dashwood,'),
#  ('Dashwood,', 'the'),
#  ('the', 'legal'),
#  ('legal', 'inheritor'),
#  ('inheritor', 'of'),
#  ('of', 'the'),
#  ('the', 'Norland'),
#  ('Norland', 'estate,'),
#  ('estate,', 'and'),
#  ('and', 'the'),
#  ('the', 'person'),
#  ('person', 'to'),
#  ('to', 'whom'),
#  ('whom', 'he'),
#  ('he', 'intended'),
#  ('intended', 'to'),
#  ('to', 'bequeath'),
#  ('bequeath', 'it.'),
#  ('it.', 'In'),
#  ('In', 'the'),
#  ('the', 'society'),
#  ('society', 'of'),
#  ('of', 'his'),
#  ('his', 'nephew'),
#  ('nephew', 'and'),
#  ('and', 'niece,'),
#  ('niece,', 'and'),
#  ('and', 'their'),
#  ('their', 'children,'),
#  ('children,', 'the'),
#  ('the', 'old'),
#  ('old', 'Gentleman’s'),
#  ('Gentleman’s', 'days'),
#  ('days', 'were'),
#  ('were', 'comfortably'),
#  ('comfortably', 'spent.'),
#  ('spent.', 'His'),
#  ('His', 'attachment'),
#  ('attachment', 'to'),
#  ('to', 'them'),
#  ('them', 'all'),
#  ('all', 'increased.'),
#  ('increased.', 'The'),
#  ('The', 'constant'),
#  ('constant', 'attention'),
#  ('attention', 'of'),
#  ('of', 'Mr.'),
#  ('Mr.', 'and'),
#  ('and', 'Mrs.'),
#  ('Mrs.', 'Henry'),
#  ('Henry', 'Dashwood'),
#  ('Dashwood', 'to'),
#  ('to', 'his'),
#  ('his', 'wishes,'),
#  ('wishes,', 'which'),
#  ('which', 'proceeded'),
#  ('proceeded', 'not'),
#  ('not', 'merely'),
#  ('merely', 'from'),
#  ('from', 'interest,'),
#  ('interest,', 'but'),
#  ('but', 'from'),
#  ('from', 'goodness'),
#  ('goodness', 'of'),
#  ('of', 'heart,'),
#  ('heart,', 'gave'),
#  ('gave', 'him'),
#  ('him', 'every'),
#  ('every', 'degree'),
#  ('degree', 'of'),
#  ('of', 'solid'),
#  ('solid', 'comfort'),
#  ('comfort', 'which'),
#  ('which', 'his'),
#  ('his', 'age'),
#  ('age', 'could'),
#  ('could', 'receive;'),
#  ('receive;', 'and'),
#  ('and', 'the'),
#  ('the', 'cheerfulness'),
#  ('cheerfulness', 'of'),
#  ('of', 'the'),
#  ('the', 'children'),
#  ('children', 'added'),
#  ('added', 'a'),
#  ('a', 'relish'),
#  ('relish', 'to'),
#  ('to', 'his'),
#  ('his', 'existence.'),
#  ('existence.', 'By'),
#  ('By', 'a'),
#  ('a', 'former'),
#  ('former', 'marriage,'),
#  ('marriage,', 'Mr.'),
#  ('Mr.', 'Henry'),
#  ('Henry', 'Dashwood'),
#  ('Dashwood', 'had'),
#  ('had', 'one'),
#  ('one', 'son:'),
#  ('son:', 'by'),
#  ('by', 'his'),
#  ('his', 'present'),
#  ('present', 'lady,'),
#  ('lady,', 'three'),
#  ('three', 'daughters.'),
#  ('daughters.', 'The'),
#  ('The', 'son,'),
#  ('son,', 'a'),
#  ('a', 'steady'),
#  ('steady', 'respectable'),
#  ('respectable', 'young'),
#  ('young', 'man,'),
#  ('man,', 'was'),
#  ('was', 'amply'),
#  ('amply', 'provided'),
#  ('provided', 'for'),
#  ('for', 'by'),
#  ('by', 'the'),
#  ('the', 'fortune'),
#  ('fortune', 'of'),
#  ('of', 'his'),
#  ('his', 'mother,'),
#  ('mother,', 'which'),
#  ('which', 'had'),
#  ('had', 'been'),
#  ('been', 'large,'),
#  ('large,', 'and'),
#  ('and', 'half'),
#  ('half', 'of'),
#  ('of', 'which'),
#  ('which', 'devolved'),
#  ('devolved', 'on'),
#  ('on', 'him'),
#  ('him', 'on'),
#  ('on', 'his'),
#  ('his', 'coming'),
#  ('coming', 'of'),
#  ('of', 'age.'),
#  ('age.', 'By'),
#  ('By', 'his'),
#  ('his', 'own'),
#  ('own', 'marriage,'),
#  ('marriage,', 'likewise,'),
#  ('likewise,', 'which'),
#  ('which', 'happened'),
#  ('happened', 'soon'),
#  ('soon', 'afterwards,'),
#  ('afterwards,', 'he'),
#  ('he', 'added'),
#  ('added', 'to'),
#  ('to', 'his'),
#  ('his', 'wealth.'),
#  ('wealth.', 'To'),
#  ('To', 'him'),
#  ('him', 'therefore'),
#  ('therefore', 'the'),
#  ('the', 'succession'),
#  ('succession', 'to'),
#  ('to', 'the'),
#  ('the', 'Norland'),
#  ('Norland', 'estate'),
#  ('estate', 'was'),
#  ('was', 'not'),
#  ('not', 'so'),
#  ('so', 'really'),
#  ('really', 'important'),
#  ('important', 'as'),
#  ('as', 'to'),
#  ('to', 'his'),
#  ('his', 'sisters;'),
#  ('sisters;', 'for'),
#  ('for', 'their'),
#  ('their', 'fortune,'),
#  ('fortune,', 'independent'),
#  ('independent', 'of'),
#  ('of', 'what'),
#  ('what', 'might'),
#  ('might', 'arise'),
#  ('arise', 'to'),
#  ('to', 'them'),
#  ('them', 'from'),
#  ('from', 'their'),
#  ('their', 'father’s'),
#  ('father’s', 'inheriting'),
#  ('inheriting', 'that'),
#  ('that', 'property,'),
#  ('property,', 'could'),
#  ('could', 'be'),
#  ('be', 'but'),
#  ('but', 'small.'),
#  ('small.', 'Their'),
#  ('Their', 'mother'),
#  ('mother', 'had'),
#  ('had', 'nothing,'),
#  ('nothing,', 'and'),
#  ('and', 'their'),
#  ('their', 'father'),
#  ('father', 'only'),
#  ('only', 'seven'),
#  ('seven', 'thousand'),
#  ('thousand', 'pounds'),
#  ('pounds', 'in'),
#  ('in', 'his'),
#  ('his', 'own'),
#  ('own', 'disposal;'),
#  ('disposal;', 'for'),
#  ('for', 'the'),
#  ('the', 'remaining'),
#  ('remaining', 'moiety'),
#  ('moiety', 'of'),
#  ('of', 'his'),
#  ('his', 'first'),
#  ('first', 'wife’s'),
#  ('wife’s', 'fortune'),
#  ('fortune', 'was'),
#  ('was', 'also'),
#  ('also', 'secured'),
#  ('secured', 'to'),
#  ('to', 'her'),
#  ('her', 'child,'),
#  ('child,', 'and'),
#  ('and', 'he'),
#  ('he', 'had'),
#  ('had', 'only'),
#  ('only', 'a'),
#  ('a', 'life-interest'),
#  ('life-interest', 'in'),
#  ('in', 'it.'),
#  ('it.', 'The'),
#  ('The', 'old'),
#  ('old', 'gentleman'),
#  ('gentleman', 'died:'),
#  ('died:', 'his'),
#  ('his', 'will'),
#  ('will', 'was'),
#  ('was', 'read,'),
#  ('read,', 'and'),
#  ('and', 'like'),
#  ('like', 'almost'),
#  ('almost', 'every'),
#  ('every', 'other'),
#  ('other', 'will,'),
#  ('will,', 'gave'),
#  ('gave', 'as'),
#  ('as', 'much'),
#  ('much', 'disappointment'),
#  ('disappointment', 'as'),
#  ('as', 'pleasure.'),
#  ('pleasure.', 'He'),
#  ('He', 'was'),
#  ('was', 'neither'),
#  ('neither', 'so'),
#  ('so', 'unjust,'),
#  ('unjust,', 'nor'),
#  ('nor', 'so'),
#  ('so', 'ungrateful,'),
#  ('ungrateful,', 'as'),
#  ('as', 'to'),
#  ('to', 'leave'),
#  ('leave', 'his'),
#  ('his', 'estate'),
#  ('estate', 'from'),
#  ('from', 'his'),
#  ('his', 'nephew;—but'),
#  ('nephew;—but', 'he'),
#  ('he', 'left'),
#  ('left', 'it'),
#  ('it', 'to'),
#  ('to', 'him'),
#  ('him', 'on'),
#  ('on', 'such'),
#  ('such', 'terms'),
#  ('terms', 'as'),
#  ('as', 'destroyed'),
#  ('destroyed', 'half'),
#  ('half', 'the'),
#  ('the', 'value'),
#  ('value', 'of'),
#  ('of', 'the'),
#  ('the', 'bequest.'),
#  ('bequest.', 'Mr.'),
#  ('Mr.', 'Dashwood'),
#  ('Dashwood', 'had'),
#  ('had', 'wished'),
#  ('wished', 'for'),
#  ('for', 'it'),
#  ('it', 'more'),
#  ('more', 'for'),
#  ('for', 'the'),
#  ('the', 'sake'),
#  ('sake', 'of'),
#  ('of', 'his'),
#  ('his', 'wife'),
#  ('wife', 'and'),
#  ('and', 'daughters'),
#  ('daughters', 'than'),
#  ('than', 'for'),
#  ('for', 'himself'),
#  ('himself', 'or'),
#  ('or', 'his'),
#  ('his', 'son;—but'),
#  ('son;—but', 'to'),
#  ('to', 'his'),
#  ('his', 'son,'),
#  ('son,', 'and'),
#  ('and', 'his'),
#  ('his', 'son’s'),
#  ('son’s', 'son,'),
#  ('son,', 'a'),
#  ('a', 'child'),
#  ('child', 'of'),
#  ('of', 'four'),
#  ('four', 'years'),
#  ('years', 'old,'),
#  ('old,', 'it'),
#  ('it', 'was'),
#  ('was', 'secured,'),
#  ('secured,', 'in'),
#  ('in', 'such'),
#  ('such', 'a'),
#  ('a', 'way,'),
#  ('way,', 'as'),
#  ('as', 'to'),
#  ('to', 'leave'),
#  ('leave', 'to'),
#  ('to', 'himself'),
#  ('himself', 'no'),
#  ('no', 'power'),
#  ('power', 'of'),
#  ('of', 'providing'),
#  ('providing', 'for'),
#  ('for', 'those'),
#  ('those', 'who'),
#  ('who', 'were'),
#  ('were', 'most'),
#  ('most', 'dear'),
#  ('dear', 'to'),
#  ('to', 'him,'),
#  ('him,', 'and'),
#  ('and', 'who'),
#  ('who', 'most'),
#  ('most', 'needed'),
#  ('needed', 'a'),
#  ('a', 'provision'),
#  ('provision', 'by'),
#  ('by', 'any'),
#  ('any', 'charge'),
#  ('charge', 'on'),
#  ('on', 'the'),
#  ('the', 'estate,'),
#  ('estate,', 'or'),
#  ('or', 'by'),
#  ('by', 'any'),
#  ('any', 'sale'),
#  ('sale', 'of'),
#  ('of', 'its'),
#  ('its', 'valuable'),
#  ('valuable', 'woods.'),
#  ('woods.', 'The'),
#  ('The', 'whole'),
#  ('whole', 'was'),
#  ('was', 'tied'),
#  ('tied', 'up'),
#  ('up', 'for'),
#  ('for', 'the'),
#  ('the', 'benefit'),
#  ('benefit', 'of'),
#  ('of', 'this'),
#  ('this', 'child,'),
#  ('child,', 'who,'),
#  ('who,', 'in'),
#  ('in', 'occasional'),
#  ('occasional', 'visits'),
#  ('visits', 'with'),
#  ('with', 'his'),
#  ('his', 'father'),
#  ('father', 'and'),
#  ('and', 'mother'),
#  ('mother', 'at'),
#  ('at', 'Norland,'),
#  ('Norland,', 'had'),
#  ('had', 'so'),
#  ('so', 'far'),
#  ('far', 'gained'),
#  ('gained', 'on'),
#  ('on', 'the'),
#  ('the', 'affections'),
#  ('affections', 'of'),
#  ('of', 'his'),
#  ('his', 'uncle,'),
#  ('uncle,', 'by'),
#  ('by', 'such'),
#  ('such', 'attractions'),
#  ('attractions', 'as'),
#  ('as', 'are'),
#  ('are', 'by'),
#  ('by', 'no'),
#  ('no', 'means'),
#  ('means', 'unusual'),
#  ('unusual', 'in'),
#  ('in', 'children'),
#  ('children', 'of'),
#  ('of', 'two'),
#  ('two', 'or'),
#  ('or', 'three'),
#  ('three', 'years'),
#  ('years', 'old;'),
#  ('old;', 'an'),
#  ('an', 'imperfect'),
#  ('imperfect', 'articulation,'),
#  ('articulation,', 'an'),
#  ('an', 'earnest'),
#  ('earnest', 'desire'),
#  ('desire', 'of'),
#  ('of', 'having'),
#  ('having', 'his'),
#  ('his', 'own'),
#  ('own', 'way,'),
#  ('way,', 'many'),
#  ('many', 'cunning'),
#  ('cunning', 'tricks,'),
#  ('tricks,', 'and'),
#  ('and', 'a'),
#  ('a', 'great'),
#  ('great', 'deal'),
#  ('deal', 'of'),
#  ('of', 'noise,'),
#  ('noise,', 'as'),
#  ('as', 'to'),
#  ('to', 'outweigh'),
#  ('outweigh', 'all'),
#  ('all', 'the'),
#  ('the', 'value'),
#  ('value', 'of'),
#  ('of', 'all'),
#  ('all', 'the'),
#  ('the', 'attention'),
#  ('attention', 'which,'),
#  ('which,', 'for'),
#  ('for', 'years,'),
#  ('years,', 'he'),
#  ('he', 'had'),
#  ('had', 'received'),
#  ('received', 'from'),
#  ('from', 'his'),
#  ('his', 'niece'),
#  ('niece', 'and'),
#  ('and', 'her'),
#  ('her', 'daughters.'),
#  ('daughters.', 'He'),
#  ('He', 'meant'),
#  ('meant', 'not'),
#  ('not', 'to'),
#  ('to', 'be'),
#  ('be', 'unkind,'),
#  ('unkind,', 'however,'),
#  ('however,', 'and,'),
#  ('and,', 'as'),
#  ('as', 'a'),
#  ('a', 'mark'),
#  ('mark', 'of'),
#  ('of', 'his'),
#  ('his', 'affection'),
#  ('affection', 'for'),
#  ('for', 'the'),
#  ('the', 'three'),
#  ('three', 'girls,'),
#  ('girls,', 'he'),
#  ('he', 'left'),
#  ('left', 'them'),
#  ('them', 'a'),
#  ('a', 'thousand'),
#  ('thousand', 'pounds'),
#  ('pounds', 'a-piece.'),
#  ('a-piece.', 'Mr.'),
#  ('Mr.', 'Dashwood’s'),
#  ('Dashwood’s', 'disappointment'),
#  ('disappointment', 'was,'),
#  ('was,', 'at'),
#  ('at', 'first,'),
#  ('first,', 'severe;'),
#  ('severe;', 'but'),
#  ('but', 'his'),
#  ('his', 'temper'),
#  ('temper', 'was'),
#  ('was', 'cheerful'),
#  ('cheerful', 'and'),
#  ('and', 'sanguine;'),
#  ('sanguine;', 'and'),
#  ('and', 'he'),
#  ('he', 'might'),
#  ('might', 'reasonably'),
#  ('reasonably', 'hope'),
#  ('hope', 'to'),
#  ('to', 'live'),
#  ('live', 'many'),
#  ('many', 'years,'),
#  ('years,', 'and'),
#  ('and', 'by'),
#  ('by', 'living'),
#  ('living', 'economically,'),
#  ('economically,', 'lay'),
#  ('lay', 'by'),
#  ('by', 'a'),
#  ('a', 'considerable'),
#  ('considerable', 'sum'),
#  ('sum', 'from'),
#  ('from', 'the'),
#  ('the', 'produce'),
#  ('produce', 'of'),
#  ('of', 'an'),
#  ('an', 'estate'),
#  ('estate', 'already'),
#  ('already', 'large,'),
#  ('large,', 'and'),
#  ('and', 'capable'),
#  ('capable', 'of'),
#  ('of', 'almost'),
#  ('almost', 'immediate'),
#  ('immediate', 'improvement.'),
#  ('improvement.', 'But'),
#  ('But', 'the'),
#  ('the', 'fortune,'),
#  ('fortune,', 'which'),
#  ('which', 'had'),
#  ('had', 'been'),
#  ('been', 'so'),
#  ('so', 'tardy'),
#  ('tardy', 'in'),
#  ('in', 'coming,'),
#  ('coming,', 'was'),
#  ('was', 'his'),
#  ('his', 'only'),
#  ('only', 'one'),
#  ('one', 'twelvemonth.'),
#  ('twelvemonth.', 'He'),
#  ('He', 'survived'),
#  ('survived', 'his'),
#  ('his', 'uncle'),
#  ('uncle', 'no'),
#  ('no', 'longer;'),
#  ('longer;', 'and'),
#  ('and', 'ten'),
#  ('ten', 'thousand'),
#  ('thousand', 'pounds,'),
#  ('pounds,', 'including'),
#  ('including', 'the'),
#  ('the', 'late'),
#  ('late', 'legacies,'),
#  ('legacies,', 'was'),
#  ('was', 'all'),
#  ('all', 'that'),
#  ('that', 'remained'),
#  ('remained', 'for'),
#  ('for', 'his'),
#  ('his', 'widow'),
#  ('widow', 'and'),
#  ('and', 'daughters.'),
#  ('daughters.', 'His'),
#  ('His', 'son'),
#  ('son', 'was'),
#  ('was', 'sent'),
#  ('sent', 'for'),
#  ('for', 'as'),
#  ('as', 'soon'),
#  ('soon', 'as'),
#  ('as', 'his'),
#  ('his', 'danger'),
#  ('danger', 'was'),
#  ('was', 'known,'),
#  ('known,', 'and'),
#  ('and', 'to'),
#  ('to', 'him'),
#  ('him', 'Mr.'),
#  ('Mr.', 'Dashwood'),
#  ('Dashwood', 'recommended,'),
#  ('recommended,', 'with'),
#  ('with', 'all'),
#  ('all', 'the'),
#  ('the', 'strength'),
#  ('strength', 'and'),
#  ('and', 'urgency'),
#  ('urgency', 'which'),
#  ('which', 'illness'),
#  ('illness', 'could'),
#  ('could', 'command,'),
#  ('command,', 'the'),
#  ('the', 'interest'),
#  ('interest', 'of'),
#  ('of', 'his'),
#  ('his', 'mother-in-law'),
#  ('mother-in-law', 'and'),
#  ('and', 'sisters.'),
#  ('sisters.', 'Mr.'),
#  ('Mr.', 'John'),
#  ('John', 'Dashwood'),
#  ('Dashwood', 'had'),
#  ('had', 'not'),
#  ('not', 'the'),
#  ('the', 'strong'),
#  ('strong', 'feelings'),
#  ('feelings', 'of'),
#  ('of', 'the'),
#  ('the', 'rest'),
#  ('rest', 'of'),
#  ('of', 'the'),
#  ('the', 'family;'),
#  ('family;', 'but'),
#  ('but', 'he'),
#  ('he', 'was'),
#  ('was', 'affected'),
#  ('affected', 'by'),
#  ('by', 'a'),
#  ('a', 'recommendation'),
#  ('recommendation', 'of'),
#  ('of', 'such'),
#  ('such', 'a'),
#  ('a', 'nature'),
#  ('nature', 'at'),
#  ('at', 'such'),
#  ('such', 'a'),
#  ('a', 'time,'),
#  ('time,', 'and'),
#  ('and', 'he'),
#  ('he', 'promised'),
#  ('promised', 'to'),
#  ('to', 'do'),
#  ('do', 'every'),
#  ('every', 'thing'),
#  ('thing', 'in'),
#  ('in', 'his'),
#  ('his', 'power'),
#  ('power', 'to'),
#  ('to', 'make'),
#  ('make', 'them'),
#  ('them', 'comfortable.'),
#  ('comfortable.', 'His'),
#  ('His', 'father'),
#  ('father', 'was'),
#  ('was', 'rendered'),
#  ('rendered', 'easy'),
#  ('easy', 'by'),
#  ('by', 'such'),
#  ('such', 'an'),
#  ('an', 'assurance,'),
#  ('assurance,', 'and'),
#  ('and', 'Mr.'),
#  ('Mr.', 'John'),
#  ('John', 'Dashwood'),
#  ('Dashwood', 'had'),
#  ('had', 'then'),
#  ('then', 'leisure'),
#  ('leisure', 'to'),
#  ('to', 'consider'),
#  ('consider', 'how'),
#  ('how', 'much'),
#  ('much', 'there'),
#  ('there', 'might'),
#  ('might', 'prudently'),
#  ('prudently', 'be'),
#  ('be', 'in'),
#  ('in', 'his'),
#  ('his', 'power'),
#  ('power', 'to'),
#  ('to', 'do'),
#  ('do', 'for'),
#  ('for', 'them.'),
#  ('them.', 'He'),
#  ('He', 'was'),
#  ('was', 'not'),
#  ('not', 'an'),
#  ('an', 'ill-disposed'),
#  ('ill-disposed', 'young'),
#  ('young', 'man,'),
#  ('man,', 'unless'),
#  ('unless', 'to'),
#  ('to', 'be'),
#  ('be', 'rather'),
#  ('rather', 'cold'),
#  ('cold', 'hearted'),
#  ('hearted', 'and'),
#  ('and', 'rather'),
#  ('rather', 'selfish'),
#  ('selfish', 'is'),
#  ('is', 'to'),
#  ('to', 'be'),
#  ('be', 'ill-disposed:'),
#  ('ill-disposed:', 'but'),
#  ('but', 'he'),
#  ('he', 'was,'),
#  ('was,', 'in'),
#  ('in', 'general,'),
#  ('general,', 'well'),
#  ('well', 'respected;'),
#  ('respected;', 'for'),
#  ('for', 'he'),
#  ('he', 'conducted'),
#  ('conducted', 'himself'),
#  ('himself', 'with'),
#  ('with', 'propriety'),
#  ('propriety', 'in'),
#  ('in', 'the'),
#  ('the', 'discharge'),
#  ('discharge', 'of'),
#  ('of', 'his'),
#  ('his', 'ordinary'),
#  ('ordinary', 'duties.'),
#  ('duties.', 'Had'),
#  ('Had', 'he'),
#  ('he', 'married'),
#  ('married', 'a'),
#  ('a', 'more'),
#  ('more', 'amiable'),
#  ('amiable', 'woman,'),
#  ('woman,', 'he'),
#  ('he', 'might'),
#  ('might', 'have'),
#  ('have', 'been'),
#  ('been', 'made'),
#  ('made', 'still'),
#  ('still', 'more'),
#  ('more', 'respectable'),
#  ('respectable', 'than'),
#  ('than', 'he'),
#  ('he', 'was:—he'),
#  ('was:—he', 'might'),
#  ('might', 'even'),
#  ('even', 'have'),
#  ('have', 'been'),
#  ('been', 'made'),
#  ('made', 'amiable'),
#  ('amiable', 'himself;'),
#  ('himself;', 'for'),
#  ('for', 'he'),
#  ('he', 'was'),
#  ('was', 'very'),
#  ('very', 'young'),
#  ('young', 'when'),
#  ('when', 'he'),
#  ('he', 'married,'),
#  ('married,', 'and'),
#  ('and', 'very'),
#  ('very', 'fond'),
#  ('fond', 'of'),
#  ('of', 'his'),
#  ('his', 'wife.'),
#  ('wife.', 'But'),
#  ('But', 'Mrs.'),
#  ('Mrs.', 'John'),
#  ('John', 'Dashwood'),
#  ('Dashwood', 'was'),
#  ('was', 'a'),
#  ('a', 'strong'),
#  ('strong', 'caricature'),
#  ('caricature', 'of'),
#  ('of', 'himself;—more'),
#  ('himself;—more', 'narrow-minded'),
#  ('narrow-minded', 'and'),
#  ('and', 'selfish.'),
#  ('selfish.', 'When'),
#  ('When', 'he'),
#  ('he', 'gave'),
#  ('gave', 'his'),
#  ('his', 'promise'),
#  ('promise', 'to'),
#  ('to', 'his'),
#  ('his', 'father,'),
#  ('father,', 'he'),
#  ('he', 'meditated'),
#  ('meditated', 'within'),
#  ...]

# %% [markdown]
# Get the rest of our Jane Austen books

# %%
raw_book = gutenbergpy.textget.get_text_by_id(1342)
pride_prejudice_text = gutenbergpy.textget.strip_headers(raw_book).decode("utf-8")

raw_book = gutenbergpy.textget.get_text_by_id(158)
emma_text = gutenbergpy.textget.strip_headers(raw_book).decode("utf-8")

raw_book = gutenbergpy.textget.get_text_by_id(105)
persuasion_text = gutenbergpy.textget.strip_headers(raw_book).decode("utf-8")



# Create our dataframe
import re
sense_sensibility_lines = sense_sensibility_text.splitlines()
pride_prejudice_lines = pride_prejudice_text.splitlines()
emma_lines = emma_text.splitlines()
persuasion_lines = persuasion_text.splitlines()

sense_sensibility_df = pd.DataFrame({
    "content": sense_sensibility_lines,
    "line": list(range(len(sense_sensibility_lines)))
})

pride_prejudice_df = pd.DataFrame({
    "content": pride_prejudice_lines,
    "line": list(range(len(pride_prejudice_lines)))
})

emma_df = pd.DataFrame({
    "content": emma_lines,
    "line": list(range(len(emma_lines)))
})

persuasion_df = pd.DataFrame({
    "content": persuasion_lines,
    "line": list(range(len(persuasion_lines)))
})


sense_sensibility_df = sense_sensibility_df.assign(book='Sense and Sensibility')
pride_prejudice_df = pride_prejudice_df.assign(book="Pride and Prejudice")
emma_df = emma_df.assign(book='Emma')
persuasion_df = persuasion_df.assign(book='Persuasion')

jane_austen_list = [sense_sensibility_df, pride_prejudice_df, emma_df, persuasion_df]
jane_austen_df = pd.concat(jane_austen_list)
jane_austen_df
# Out:
#              content  line                   book
# 0                        0  Sense and Sensibility
# 1     [Illustration]     1  Sense and Sensibility
# 2                        2  Sense and Sensibility
# 3                        3  Sense and Sensibility
# 4                        4  Sense and Sensibility
# ...              ...   ...                    ...
# 8341                  8341             Persuasion
# 8342                  8342             Persuasion
# 8343                  8343             Persuasion
# 8344                  8344             Persuasion
# 8345                  8345             Persuasion
#
# [51724 rows x 3 columns]

# %%
from nltk import *

# Use nltk's ngrams() built-in function

sense_sensibility_bigrams_generator = ngrams(word_tokenize(sense_sensibility_text.lower()), 2)
sense_sensibility_bigrams = [ ' '.join(grams) for grams in sense_sensibility_bigrams_generator]

sense_sensibility_df = pd.DataFrame({
    "book": "Sense and Sensibility",
    "bigrams": sense_sensibility_bigrams,
})

# %%
pride_prejudice_bigrams_generator = ngrams(word_tokenize(pride_prejudice_text.lower()), 2)
pride_prejudice_bigrams = [ ' '.join(grams) for grams in pride_prejudice_bigrams_generator]
pride_prejudice_df = pd.DataFrame({
    "book": "Pride and Prejudice",
    "bigrams": pride_prejudice_bigrams,
})

emma_bigrams_generator = ngrams(word_tokenize(emma_text.lower()), 2)
emma_bigrams = [ ' '.join(grams) for grams in emma_bigrams_generator]
emma_df = pd.DataFrame({
    "book": "Emma",
    "bigrams": emma_bigrams,
})

persuasion_bigrams_generator = ngrams(word_tokenize(persuasion_text.lower()), 2)
persuasion_bigrams = [ ' '.join(grams) for grams in persuasion_bigrams_generator]
persuasion_df = pd.DataFrame({
    "book": "Persuasion",
    "bigrams": persuasion_bigrams,
})

# %%
# We've created our bigrams dataframe (albeit not clean yet, but we'll deal with stop words later)
jane_austen_list = [sense_sensibility_df, pride_prejudice_df, emma_df, persuasion_df]
jane_austen_df = pd.concat(jane_austen_list)
jane_austen_df
# Out:
#                         book              bigrams
# 0      Sense and Sensibility       [ illustration
# 1      Sense and Sensibility       illustration ]
# 2      Sense and Sensibility              ] sense
# 3      Sense and Sensibility            sense and
# 4      Sense and Sensibility      and sensibility
# ...                      ...                  ...
# 97849             Persuasion               in its
# 97850             Persuasion         its national
# 97851             Persuasion  national importance
# 97852             Persuasion         importance .
# 97853             Persuasion              . finis
#
# [567634 rows x 2 columns]

# %%
# Let's see what the most common bigrams look like

from siuba import *
jane_austen_count = count(jane_austen_df, _.book, _.bigrams, sort=True)
jane_austen_count
# Out:
#                          book         bigrams     n
# 0                        Emma           , and  1880
# 1         Pride and Prejudice           , and  1639
# 2       Sense and Sensibility           , and  1601
# 3                  Persuasion           , and  1267
# 4                        Emma             ” “   987
# ...                       ...             ...   ...
# 211769             Persuasion         shore ;     1
# 211770             Persuasion  shore admitted     1
# 211771             Persuasion        shore at     1
# 211772             Persuasion        short ''     1
# 211773             Persuasion     you courage     1
#
# [211774 rows x 3 columns]

# %%
# We’ve got problems with our data cleaning. We’ll try to take care of it in a bit.
# However, first we’ll try to split these bigrams into the words that they are comprised of and add them to our df.


jane_austen_df[['word1', 'word2']] = jane_austen_df['bigrams'].str.split(expand=True)
jane_austen_df
# Out:
#                         book              bigrams         word1         word2
# 0      Sense and Sensibility       [ illustration             [  illustration
# 1      Sense and Sensibility       illustration ]  illustration             ]
# 2      Sense and Sensibility              ] sense             ]         sense
# 3      Sense and Sensibility            sense and         sense           and
# 4      Sense and Sensibility      and sensibility           and   sensibility
# ...                      ...                  ...           ...           ...
# 97849             Persuasion               in its            in           its
# 97850             Persuasion         its national           its      national
# 97851             Persuasion  national importance      national    importance
# 97852             Persuasion         importance .    importance             .
# 97853             Persuasion              . finis             .         finis
#
# [567634 rows x 4 columns]

# %% [markdown]
# # Exercise 2 - Clean Bigrams

# %%
# Write your code below
# We've added some stop words lists to help you in your cleaning

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

basic_stop_words = stopwords.words('english')
punctuation_signs = ['\'', "''", ';', '"', ',', '.', '!', '?', '/', '[', ']', '(', ')', '“', '”', '’', '‘', '``', "--", "{", "}", "|"]
custom_stop_words = ["a","about","above","after","again","against","ain","all","am","an","and","any","are","aren","aren't","as","at","be","because","been","before","being","below","between","both","but","by","can","couldn","couldn't","d","did","didn","didn't","do","does","doesn","doesn't","doing","don","don't","down","during","each","few","for","from","further","had","hadn","hadn't","has","hasn","hasn't","have","haven","haven't","having","he","her","here","hers","herself","him","himself","his","how","i","if","in","into","is","isn","isn't","it","it's","its","itself","just","ll","m","ma","me","mightn","mightn't","more","most","mustn","mustn't","my","myself","needn","needn't","no","nor","not","now","o","of","off","on","once","only","or","other","our","ours","ourselves","out","over","own","re","s","same","shan","shan't","she","she's","should","should've","shouldn","shouldn't","so","some","such","t","than","that","that'll","the","their","theirs","them","themselves","then","there","these","they","this","those","through","to","too","under","until","up","ve","very","was","wasn","wasn't","we","were","weren","weren't","what","when","where","which","while","who","whom","why","will","with","won","won't","wouldn","wouldn't","y","you","you'd","you'll","you're","you've","your","yours","yourself","yourselves","could","he'd","he'll","he's","here's","how's","i'd","i'll","i'm","i've","let's","ought","she'd","she'll","that's","there's","they'd","they'll","they're","they've","we'd","we'll","we're","we've","what's","when's","where's","who's","why's","would","able","abst","accordance","according","accordingly","across","act","actually","added","adj","affected","affecting","affects","afterwards","ah","almost","alone","along","already","also","although","always","among","amongst","announce","another","anybody","anyhow","anymore","anyone","anything","anyway","anyways","anywhere","apparently","approximately","arent","arise","around","aside","ask","asking","auth","available","away","awfully","b","back","became","become","becomes","becoming","beforehand","begin","beginning","beginnings","begins","behind","believe","beside","besides","beyond","biol","brief","briefly","c","ca","came","cannot","can't","cause","causes","certain","certainly","co","com","come","comes","contain","containing","contains","couldnt","date","different","done","downwards","due","e","ed","edu","effect","eg","eight","eighty","either","else","elsewhere","end","ending","enough","especially","et","etc","even","ever","every","everybody","everyone","everything","everywhere","ex","except","f","far","ff","fifth","first","five","fix","followed","following","follows","former","formerly","forth","found","four","furthermore","g","gave","get","gets","getting","give","given","gives","giving","go","goes","gone","got","gotten","h","happens","hardly","hed","hence","hereafter","hereby","herein","heres","hereupon","hes","hi","hid","hither","home","howbeit","however","hundred","id","ie","im","immediate","immediately","importance","important","inc","indeed","index","information","instead","invention","inward","itd","it'll","j","k","keep","keeps","kept","kg","km","know","known","knows","l","largely","last","lately","later","latter","latterly","least","less","lest","let","lets","like","liked","likely","line","little","'ll","look","looking","looks","ltd","made","mainly","make","makes","many","may","maybe","mean","means","meantime","meanwhile","merely","mg","might","million","miss","ml","moreover","mostly","mr","mrs","much","mug","must","n","na","name","namely","nay","nd","near","nearly","necessarily","necessary","need","needs","neither","never","nevertheless","new","next","nine","ninety","nobody","non","none","nonetheless","noone","normally","nos","noted","nothing","nowhere","obtain","obtained","obviously","often","oh","ok","okay","old","omitted","one","ones","onto","ord","others","otherwise","outside","overall","owing","p","page","pages","part","particular","particularly","past","per","perhaps","placed","please","plus","poorly","possible","possibly","potentially","pp","predominantly","present","previously","primarily","probably","promptly","proud","provides","put","q","que","quickly","quite","qv","r","ran","rather","rd","readily","really","recent","recently","ref","refs","regarding","regardless","regards","related","relatively","research","respectively","resulted","resulting","results","right","run","said","saw","say","saying","says","sec","section","see","seeing","seem","seemed","seeming","seems","seen","self","selves","sent","seven","several","shall","shed","shes","show","showed","shown","showns","shows","significant","significantly","similar","similarly","since","six","slightly","somebody","somehow","someone","somethan","something","sometime","sometimes","somewhat","somewhere","soon","sorry","specifically","specified","specify","specifying","still","stop","strongly","sub","substantially","successfully","sufficiently","suggest","sup","sure","take","taken","taking","tell","tends","th","thank","thanks","thanx","thats","that've","thence","thereafter","thereby","thered","therefore","therein","there'll","thereof","therere","theres","thereto","thereupon","there've","theyd","theyre","think","thou","though","thoughh","thousand","throug","throughout","thru","thus","til","tip","together","took","toward","towards","tried","tries","truly","try","trying","ts","twice","two","u","un","unfortunately","unless","unlike","unlikely","unto","upon","ups","us","use","used","useful","usefully","usefulness","uses","using","usually","v","value","various","'ve","via","viz","vol","vols","vs","w","want","wants","wasnt","way","wed","welcome","went","werent","whatever","what'll","whats","whence","whenever","whereafter","whereas","whereby","wherein","wheres","whereupon","wherever","whether","whim","whither","whod","whoever","whole","who'll","whomever","whos","whose","widely","willing","wish","within","without","wont","words","world","wouldnt","www","x","yes","yet","youd","youre","z","zero","a's","ain't","allow","allows","apart","appear","appreciate","appropriate","associated","best","better","c'mon","c's","cant","changes","clearly","concerning","consequently","consider","considering","corresponding","course","currently","definitely","described","despite","entirely","exactly","example","going","greetings","hello","help","hopefully","ignored","inasmuch","indicate","indicated","indicates","inner","insofar","it'd","keep","keeps","novel","presumably","reasonably","second","secondly","sensible","serious","seriously","sure","t's","third","thorough","thoroughly","three","well","wonder"]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bogda\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# 1. Clean the dataframe of all stop words.

# %%
all_stopwords = basic_stop_words + punctuation_signs + custom_stop_words
# reamove stopwords
jane_austen_clean_df = jane_austen_df[~jane_austen_df['word1'].isin(all_stopwords)]
jane_austen_clean_df = jane_austen_clean_df[~jane_austen_clean_df['word2'].isin(all_stopwords)]

jane_austen_clean_df
# Out:
#                         book           bigrams     word1    word2
# 7      Sense and Sensibility       jane austen      jane   austen
# 12     Sense and Sensibility  contents chapter  contents  chapter
# 15     Sense and Sensibility        chapter ii   chapter       ii
# 16     Sense and Sensibility        ii chapter        ii  chapter
# 17     Sense and Sensibility       chapter iii   chapter      iii
# ...                      ...               ...       ...      ...
# 97804             Persuasion        future war    future      war
# 97818             Persuasion         sailor 's    sailor       's
# 97819             Persuasion           's wife        's     wife
# 97829             Persuasion       quick alarm     quick    alarm
# 97846             Persuasion  domestic virtues  domestic  virtues
#
# [30754 rows x 4 columns]

# %% [markdown]
# 2. Show the most commonly occurring bigrams after data cleaning.

# %%
jane_austen_clean_bigram = count(jane_austen_clean_df, _.bigrams, sort=True)
jane_austen_clean_bigram
# Out:
#                          bigrams    n
# 0                  mr. knightley  264
# 1                      mr. darcy  258
# 2                    mrs. weston  242
# 3                  mrs. jennings  231
# 4                      mr. elton  210
# ...                          ...  ...
# 19918                fixed here.    1
# 19919             fixed attitude    1
# 19920      five-and-twenty miles    1
# 19921  five-and-twenty children.    1
# 19922              instantly set    1
#
# [19923 rows x 2 columns]

# %% [markdown]
# 3. Plot the most commonly occurring 10 bigrams after data cleaning using a plotting library of your choice.

# %%
from plotnine import *

ggplot(jane_austen_clean_bigram.head(10)) \
    + aes(x='bigrams', y='n') \
    + geom_col() \
    + coord_flip() \
    + scale_x_discrete()
# Out:
# <ggplot: (193721104156)>

# %% [markdown]
# # Exercise 3 - Clean Trigrams
#
# 1. Create your own trigrams dataframe similarly to how we've created the bigrams one. (hint: give 3 as parameter to ngrams function)

# %%
def create_trigram_df(text, title):
    trigram_gen = ngrams(word_tokenize(text.lower()), 3)

    trigrams = [' '.join(grams) for grams in trigram_gen]

    df = pd.DataFrame({
        "book": title,
        "trigrams": trigrams,
    })
    
    return df

# %%
jane_austen_list = [
    {'text': sense_sensibility_text, 'title': "Sense and Sensibility"},
    {'text': pride_prejudice_text, 'title': "Pride and Prejudice"},
    {'text': emma_text, 'title': "Emma"},
    {'text': persuasion_text, 'title': "Persuasion"},
]
jane_austen_trigrams = pd.concat(list(map(lambda x: create_trigram_df(x['text'], x['title']), jane_austen_list)))
jane_austen_trigrams[['word1', 'word2', 'word3']] = jane_austen_trigrams['trigrams'].str.split(expand=True)
jane_austen_trigrams
# Out:
#                         book                 trigrams         word1  \
# 0      Sense and Sensibility         [ illustration ]             [
# 1      Sense and Sensibility     illustration ] sense  illustration
# 2      Sense and Sensibility              ] sense and             ]
# 3      Sense and Sensibility    sense and sensibility         sense
# 4      Sense and Sensibility       and sensibility by           and
# ...                      ...                      ...           ...
# 97848             Persuasion              than in its          than
# 97849             Persuasion          in its national            in
# 97850             Persuasion  its national importance           its
# 97851             Persuasion    national importance .      national
# 97852             Persuasion       importance . finis    importance
#
#               word2        word3
# 0      illustration            ]
# 1                 ]        sense
# 2             sense          and
# 3               and  sensibility
# 4       sensibility           by
# ...             ...          ...
# 97848            in          its
# 97849           its     national
# 97850      national   importance
# 97851    importance            .
# 97852             .        finis
#
# [567630 rows x 5 columns]

# %% [markdown]
# 2. Get rid of stop words (hint: treat 's as a stop word if it pollutes your results)

# %%
all_stopwords += ['\'s']

jane_austen_trigrams_clean = jane_austen_trigrams[~jane_austen_trigrams['word1'].isin(all_stopwords)]
jane_austen_trigrams_clean = jane_austen_trigrams_clean[~jane_austen_trigrams_clean['word2'].isin(all_stopwords)]
jane_austen_trigrams_clean = jane_austen_trigrams_clean[~jane_austen_trigrams_clean['word3'].isin(all_stopwords)]

jane_austen_trigrams_clean
# Out:
#                         book                       trigrams    word1  \
# 15     Sense and Sensibility             chapter ii chapter  chapter
# 16     Sense and Sensibility                 ii chapter iii       ii
# 17     Sense and Sensibility            chapter iii chapter  chapter
# 18     Sense and Sensibility                 iii chapter iv      iii
# 19     Sense and Sensibility             chapter iv chapter  chapter
# ...                      ...                            ...      ...
# 96646             Persuasion        pretty completely wrong   pretty
# 97040             Persuasion             keeping sir walter  keeping
# 97041             Persuasion              sir walter single      sir
# 97317             Persuasion         love captain wentworth     love
# 97781             Persuasion  captain wentworth's affection  captain
#
#              word2      word3
# 15              ii    chapter
# 16         chapter        iii
# 17             iii    chapter
# 18         chapter         iv
# 19              iv    chapter
# ...            ...        ...
# 96646   completely      wrong
# 97040          sir     walter
# 97041       walter     single
# 97317      captain  wentworth
# 97781  wentworth's  affection
#
# [3978 rows x 5 columns]

# %% [markdown]
# 3. Show the most common trigrams from the dataframe. Plotting is not necessary.

# %%
jane_austen_trigrams_clean_count = count(jane_austen_trigrams_clean, _.trigrams, sort=True)

jane_austen_trigrams_clean_count
# Out:
#                         trigrams   n
# 0            mr. frank churchill  44
# 1             mr. john knightley  28
# 2             mrs. john dashwood  24
# 3              lady catherine de  14
# 4            catherine de bourgh  13
# ...                          ...  ..
# 3587        felt equal amazement   1
# 3588    felt tolerably persuaded   1
# 3589  ferrars looked exceedingly   1
# 3590            ferrars told me.   1
# 3591     ——shire militia removed   1
#
# [3592 rows x 2 columns]

# %% [markdown]
# ### N-grams ideas
#
# Let's get creative with our bigrams and trigrams now that we have them.
#
# We can try to look for instance at what are the most frequently mentioned streets in each book.
#
# We’ll create a new df where the stop words are not removed, there might be some that we don’t want to get rid of just yet.

# %%
from siuba import *

jane_austen_list = [sense_sensibility_df, pride_prejudice_df, emma_df, persuasion_df]
jane_austen_test_df = pd.concat(jane_austen_list)
jane_austen_test_df[['word1', 'word2']] = jane_austen_test_df['bigrams'].str.split(expand=True)

count(filter(jane_austen_test_df, _.word2=='street'), _.book, _.word1, _.word2, sort=True)
# Out:
#                      book        word1   word2   n
# 0   Sense and Sensibility       harley  street  16
# 1   Sense and Sensibility     berkeley  street  16
# 2     Pride and Prejudice  gracechurch  street   9
# 3   Sense and Sensibility      conduit  street   6
# 4     Pride and Prejudice          the  street   6
# 5              Persuasion          the  street   6
# 6              Persuasion       milsom  street   5
# 7                    Emma          the  street   5
# 8   Sense and Sensibility         bond  street   4
# 9              Persuasion       rivers  street   4
# 10             Persuasion        union  street   3
# 11  Sense and Sensibility          the  street   3
# 12             Persuasion          gay  street   2
# 13             Persuasion         bath  street   2
# 14             Persuasion      steeper  street   1
# 15    Pride and Prejudice    grosvenor  street   1
# 16             Persuasion     pulteney  street   1
# 17    Pride and Prejudice           ——  street   1
# 18             Persuasion    principal  street   1
# 19             Persuasion         bond  street   1
# 20  Sense and Sensibility        james  street   1
# 21  Sense and Sensibility         park  street   1
# 22  Sense and Sensibility    sackville  street   1
# 23                   Emma         main  street   1

# %% [markdown]
# ### N-grams and tf-idf
# We could aso make use of the previous laboratory’s tf-idf analysis - keep in mind that bigrams or trigrams can be treated as a singular unit.

# %%
from siuba import *
from tidytext import *

jane_austen_freq = count(jane_austen_df, _.book, _.bigrams, _.word1, _.word2, sort=True)
jane_austen_tf_idf = bind_tf_idf(jane_austen_freq, 'bigrams', 'book', 'n')

graph_jane_austen = ungroup(group_by(arrange(jane_austen_tf_idf, -_.tf_idf), 'book').head(8))

ordered_graph_jane_austen = arrange(graph_jane_austen, _.book, -_.tf_idf)
ordered_graph_jane_austen
# Out:
#                       book            bigrams     word1      word2    n  \
# 70                    Emma      mr. knightley       mr.  knightley  264
# 84                    Emma        mrs. weston      mrs.     weston  242
# 117                   Emma          mr. elton       mr.      elton  210
# 4                     Emma                ” “         ”          “  987
# 5                     Emma                ’ s         ’          s  914
# 147                   Emma             emma ,      emma          ,  181
# 199                   Emma     miss woodhouse      miss  woodhouse  157
# 203                   Emma         mr. weston       mr.     weston  155
# 38              Persuasion               . ''         .         ''  369
# 78              Persuasion              '' ``        ''         ``  254
# 99              Persuasion               , ''         ,         ''  229
# 134             Persuasion               . ``         .         ``  196
# 136             Persuasion  captain wentworth   captain  wentworth  190
# 166             Persuasion          mr elliot        mr     elliot  171
# 179             Persuasion               , ``         ,         ``  163
# 220             Persuasion       lady russell      lady    russell  144
# 72     Pride and Prejudice          mr. darcy       mr.      darcy  258
# 7      Pride and Prejudice                ” “         ”          “  836
# 207    Pride and Prejudice        mrs. bennet      mrs.     bennet  151
# 217    Pride and Prejudice        mr. collins       mr.    collins  145
# 10     Pride and Prejudice                ’ s         ’          s  644
# 311    Pride and Prejudice     lady catherine      lady  catherine  116
# 337    Pride and Prejudice        mr. bingley       mr.    bingley  109
# 371    Pride and Prejudice            darcy ,     darcy          ,  103
# 98   Sense and Sensibility      mrs. jennings      mrs.   jennings  231
# 113  Sense and Sensibility           elinor ,    elinor          ,  213
# 159  Sense and Sensibility         marianne ,  marianne          ,  176
# 8    Sense and Sensibility                ’ s         ’          s  689
# 11   Sense and Sensibility                ” “         ”          “  628
# 265  Sense and Sensibility    colonel brandon   colonel    brandon  127
# 287  Sense and Sensibility      mrs. dashwood      mrs.   dashwood  121
# 330  Sense and Sensibility           sir john       sir       john  111
#
#            tf       idf    tf_idf
# 70   0.001414  1.386294  0.001960
# 84   0.001296  1.386294  0.001796
# 117  0.001124  1.386294  0.001559
# 4    0.005285  0.287682  0.001520
# 5    0.004894  0.287682  0.001408
# 147  0.000969  1.386294  0.001344
# 199  0.000841  1.386294  0.001165
# 203  0.000830  1.386294  0.001151
# 38   0.003771  1.386294  0.005228
# 78   0.002596  1.386294  0.003598
# 99   0.002340  1.386294  0.003244
# 134  0.002003  1.386294  0.002777
# 136  0.001942  1.386294  0.002692
# 166  0.001748  1.386294  0.002423
# 179  0.001666  1.386294  0.002309
# 220  0.001472  1.386294  0.002040
# 72   0.001808  1.386294  0.002506
# 7    0.005858  0.287682  0.001685
# 207  0.001058  1.386294  0.001467
# 217  0.001016  1.386294  0.001408
# 10   0.004512  0.287682  0.001298
# 311  0.000813  1.386294  0.001127
# 337  0.000764  1.386294  0.001059
# 371  0.000722  1.386294  0.001000
# 98   0.001646  1.386294  0.002282
# 113  0.001518  1.386294  0.002105
# 159  0.001254  1.386294  0.001739
# 8    0.004911  0.287682  0.001413
# 11   0.004476  0.287682  0.001288
# 265  0.000905  1.386294  0.001255
# 287  0.000862  1.386294  0.001196
# 330  0.000791  1.386294  0.001097

# %% [markdown]
# We’ll take the top 8 highest tf-idf bigrams in each book and plot them (ideally you'll want to get rid of stop words)

# %%
from plotnine import *
from siuba.dply.forcats import fct_lump, fct_reorder
ggplot(ordered_graph_jane_austen) + aes(x=fct_reorder(ordered_graph_jane_austen['bigrams'], x=ordered_graph_jane_austen['tf_idf']), y='tf_idf', fill='book') + coord_flip() + geom_col(show_legend = False) + facet_wrap('~book', ncol = 2, scales = "free") + labs(x = "tf-idf", y = None) + theme(subplots_adjust={'wspace': 0.15}) + theme(subplots_adjust={'wspace': 0.85, 'hspace': 0.3}) + scale_x_discrete()
# Out:
# C:\Python310\lib\site-packages\plotnine\utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (193720442175)>

# %% [markdown]
# ### N-grams and sentiment analysis
#
# Another idea could be combining sentiment analysis with n-grams.
#
# Let's see how badly afinn's naiveness affected us in our sentiment analysis. We'll try to analyze all of the words that got negated by 'not' and for which afinn gave false sentiment values. This is why we kept the stop words, in order to not lose the 'not'.

# %%
# We'll take all the bigrams that start with the word 'not'
from siuba import *
count(filter(jane_austen_df, _.word1 == 'not'), _.word1, _.word2, sort=True)
# Out:
#      word1     word2    n
# 0      not        be  486
# 1      not        to  225
# 2      not      have  218
# 3      not      know  161
# 4      not         a  136
# ...    ...       ...  ...
# 1035   not       ill    1
# 1036   not  ill-used    1
# 1037   not  imagine.    1
# 1038   not    impute    1
# 1039   not        —i    1
#
# [1040 rows x 3 columns]

# %%
from afinn import Afinn
afinn = Afinn()

# Split words into positive and negative
afinn_positive = {k: v for k, v in afinn._dict.items() if v > 0}
afinn_negative = {k: v for k, v in afinn._dict.items() if v < 0}

# %%
# A look at what positive bigrams look like
jane_austen_df[jane_austen_df.word2.isin(afinn_positive)]
# Out:
#                         book              bigrams     word1          word2
# 161    Sense and Sensibility            to engage        to         engage
# 164    Sense and Sensibility         general good   general           good
# 187    Sense and Sensibility        very advanced      very       advanced
# 223    Sense and Sensibility              a great         a          great
# 252    Sense and Sensibility            the legal       the          legal
# ...                      ...                  ...       ...            ...
# 97794             Persuasion         friends wish   friends           wish
# 97796             Persuasion      that tenderness      that     tenderness
# 97810             Persuasion         her sunshine       her       sunshine
# 97842             Persuasion   more distinguished      more  distinguished
# 97851             Persuasion  national importance  national     importance
#
# [20511 rows x 4 columns]

# %%
# A look at what negative bigrams look like
jane_austen_df[jane_austen_df.word2.isin(afinn_negative)]
# Out:
#                         book              bigrams      word1           word2
# 211    Sense and Sensibility            her death        her           death
# 233    Sense and Sensibility             her loss        her            loss
# 519    Sense and Sensibility       gentleman died  gentleman            died
# 536    Sense and Sensibility  much disappointment       much  disappointment
# 544    Sense and Sensibility            so unjust         so          unjust
# ...                      ...                  ...        ...             ...
# 97701             Persuasion             not fail        not            fail
# 97800             Persuasion            the dread        the           dread
# 97804             Persuasion           future war     future             war
# 97824             Persuasion             must pay       must             pay
# 97829             Persuasion          quick alarm      quick           alarm
#
# [13409 rows x 4 columns]

# %%
# Now we’ll make a separate dataframe containing the positive and negative words.
# We’ll filter the bigrams that have ‘not’ as first word from our Jane Austen dataframe. 
# We’ll then (inner) join this filtered dataframe with the afinn one that we created in order to keep only the entries where word2 is a negative or positive word (and keep its sentiment value).
# Now a simple count helps us see how often each positive/negative 2nd word appears when the first word is 'not'.


from siuba import *
afinn_df = pd.DataFrame({'word': afinn._dict.keys(), 'value' : afinn._dict.values()})
not_sentiment_contribution = count(join(filter(jane_austen_df, _.word1 == 'not'), afinn_df, how = "inner", on = {"word2": "word"}), _.word2, _.value, sort=True)
not_sentiment_contribution
# Out:
#          word2  value   n
# 0         help      2  68
# 1         like      2  52
# 2        allow      1  30
# 3         wish      1  29
# 4         want      1  26
# ..         ...    ...  ..
# 219  fortunate      2   1
# 220       gain      2   1
# 221    granted      1   1
# 222      great      3   1
# 223      wrong     -2   1
#
# [224 rows x 3 columns]

# %%
from siuba import *

# Add a new column with the total sentimental contribution to the books of each word (sentiment value * number of occurrences)
not_sentiment_contribution = not_sentiment_contribution.assign(contribution=not_sentiment_contribution.value*not_sentiment_contribution.n)

# Keep the first 20 strongest contributions in either direction. Use absolute value for this.
first_20_contribs = arrange(not_sentiment_contribution, -abs(_.contribution)).head(20)
first_20_contribs
# Out:
#         word2  value   n  contribution
# 0        help      2  68           136
# 1        like      2  52           104
# 2       allow      1  30            30
# 3        wish      1  29            29
# 4        want      1  26            26
# 8        care      2  13            26
# 9        fail     -2  13           -26
# 11       deny     -2  12           -24
# 16   handsome      3   8            24
# 18       love      3   8            24
# 20  perfectly      3   8            24
# 12     afraid     -2  11           -22
# 13      worth      2  11            22
# 14     refuse     -2   9           -18
# 5     pretend     -1  16           -16
# 19      blame     -2   8           -16
# 6       leave     -1  15           -15
# 7       sorry     -1  15           -15
# 31    deceive     -3   5           -15
# 10      doubt     -1  13           -13

# %%
# Can use a simple matplotlib plot for this

import numpy as np
import matplotlib.pyplot as plt

x=first_20_contribs['word2']
y=first_20_contribs['contribution']
mask1 = y < 0
mask2 = y >= 0

plt.figure(figsize=(8, 12))

#plot3: barh with correct order: top-down y axis

plt.barh(x[mask2],y[mask2], color='green')
plt.barh(x[mask1],y[mask1], color='red')

plt.gca().invert_yaxis()

# %% [markdown]
# It’s obvious that there is more positive contribution that is false than there is false negative contribution. The bigram "not help" is the one that contributes falsely the most. The fact that the word 'help' is preceded by 'not' means that when afinn calculates the total sentiment of the book, the contribution of this bigram will always be positive, when in fact it should be negative.
# We can conclude that the overall sentiment of the book (although probably still a positive one) is less positive than we had initially thought.

# %% [markdown]
# Exercise 4
#
# 1. Choose four books of your choice (different than the ones from Jane Austen) and create a bigram dataframe for them.

# %%
def create_df(book_id, book_name, ngram):
    raw_book = gutenbergpy.textget.get_text_by_id(book_id)
    text = gutenbergpy.textget.strip_headers(raw_book).decode("utf-8")

    ngram_gen = ngrams(word_tokenize(text.lower()), ngram)
    ngrams_list = [ ' '.join(grams) for grams in ngram_gen]
    
    df = pd.DataFrame({
        "book": book_name,
        f"{ngram}grams": ngrams_list,
    })
    
    
    df[[f'word{n}' for n in range(1, ngram+1)]] = df[f"{ngram}grams"].str.split(expand=True)
    # filter n-grams for stopwords
    for word_num in range(1, ngram + 1):
        df = df[~df[f'word{word_num}'].isin(punctuation_signs)]
    
    return df

# %%
books = [
    {'id': 46963, 'name': 'Astrology'},
    {'id': 43548, 'name': 'Tarot'},
    {'id': 27755, 'name': 'Alchemy'},
    {'id': 42008, 'name': 'Fortune Telling'}
]

dfs = pd.concat(list(map(lambda x: create_df(x['id'], x['name'], 2), books)))

dfs
# Out:
#                   book                    2grams        word1         word2
# 0            Astrology                reiner ruf       reiner           ruf
# 3            Astrology                   and the          and           the
# 4            Astrology                the online          the        online
# 5            Astrology        online distributed       online   distributed
# 6            Astrology  distributed proofreading  distributed  proofreading
# ...                ...                       ...          ...           ...
# 37119  Fortune Telling                    526 w.          526            w.
# 37120  Fortune Telling                     w. 26           w.            26
# 37121  Fortune Telling                    26 st.           26           st.
# 37122  Fortune Telling                   st. new          st.           new
# 37123  Fortune Telling                  new york          new          york
#
# [184126 rows x 4 columns]

# %% [markdown]
# 2. Perform a similar analysis to the one where we looked for popular street names in our books. Be creative, anything goes, but don't perform the same exact analysis (don't look for street names). Plotting is not necessary

# %%
count(filter(dfs, _.word2=='luck'), _.book, _.word1, _.word2, sort=True)
# Out:
#               book  word1 word2   n
# 0  Fortune Telling   good  luck  10
# 1            Tarot  their  luck   2
# 2          Alchemy   good  luck   1
# 3          Alchemy     no  luck   1
# 4  Fortune Telling   show  luck   1
# 5  Fortune Telling    the  luck   1

# %% [markdown]
# 3. Plot the most important 8 bigrams from each book based on their tf-idf score.

# %%
dfs_count = count(dfs, _.book, _["2grams"], _.word1, _.word2, sort=True)
dfs_tf_idf = bind_tf_idf(dfs_count, '2grams', 'book', 'n')

dfs_tf_idf = ungroup(group_by(arrange(dfs_tf_idf, -_.tf_idf), 'book').head(8))

dfs_tf_idf = arrange(dfs_tf_idf, _.book, -_.tf_idf)

ggplot(dfs_tf_idf) \
    + aes(x=fct_reorder(dfs_tf_idf['2grams'], x=dfs_tf_idf['tf_idf']), y='tf_idf', fill='book') \
    + coord_flip()\
    + geom_col(show_legend = False) \
    + facet_wrap('~book', ncol = 2, scales = "free") \
    + labs(x = "tf-idf", y = None) \
    + theme(subplots_adjust={'wspace': 0.15}) \
    + theme(subplots_adjust={'wspace': 0.85, 'hspace': 0.3}) \
    + scale_x_discrete()
# Out:
# C:\Python310\lib\site-packages\plotnine\utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (193721077812)>

# %% [markdown]
# 4. Perform a similar analysis to the one where we looked at words that most commonly occur after 'not' and contribute the opposite sentiment than afinn would have us believe. Use a different negation than 'not'. Plot the top 20 false contributions (use absolute value for your sorting).

# %%
df_bad = filter(dfs, _.word1 == 'no')
df_bad = count(join(df_bad, afinn_df, how = "inner", on = {"word2": "word"}), _.word2, _.value, sort=True)
df_bad['contribution'] = df_bad['value'] * df_bad['n']
df_bad = arrange(df_bad, -abs(_.contribution)).head(20)


x=df_bad['word2']
y=df_bad['contribution']
mask1 = y < 0
mask2 = y >= 0

plt.figure(figsize=(8, 12))

#plot3: barh with correct order: top-down y axis

plt.barh(x[mask2],y[mask2], color='green')
plt.barh(x[mask1],y[mask1], color='red')

plt.gca().invert_yaxis()

# %% [markdown]
# # Networks
# Now it’s time to plot a network-like graph to show the connections between the words
#
# We’ll first convert our dataframe such that we only have the information required for creating an actual nodes graph. We will have the nodes (the words from word1 and word2) and will know that they have an edge between them (with weight = n, but that is of no particular interest)

# %%
from siuba import *
jane_austen_graph_df = jane_austen_test_df.drop(columns=['book'])
j_a_graph_df = count(jane_austen_graph_df, _.bigrams, _.word1, _.word2, sort=True).drop(columns=['bigrams'])

# %%
# We’ll then clean the dataframe (remove stopwords)
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

remove_words = []

punctuation_signs = ['\'', "''", ';', '"', ',', '.', '!', '?', '/', '[', ']', '(', ')', '“', '”', '’', '‘', '``', "--"]
custom_stop_words = ["a","about","above","after","again","against","ain","all","am","an","and","any","are","aren","aren't","as","at","be","because","been","before","being","below","between","both","but","by","can","couldn","couldn't","d","did","didn","didn't","do","does","doesn","doesn't","doing","don","don't","down","during","each","few","for","from","further","had","hadn","hadn't","has","hasn","hasn't","have","haven","haven't","having","he","her","here","hers","herself","him","himself","his","how","i","if","in","into","is","isn","isn't","it","it's","its","itself","just","ll","m","ma","me","mightn","mightn't","more","most","mustn","mustn't","my","myself","needn","needn't","no","nor","not","now","o","of","off","on","once","only","or","other","our","ours","ourselves","out","over","own","re","s","same","shan","shan't","she","she's","should","should've","shouldn","shouldn't","so","some","such","t","than","that","that'll","the","their","theirs","them","themselves","then","there","these","they","this","those","through","to","too","under","until","up","ve","very","was","wasn","wasn't","we","were","weren","weren't","what","when","where","which","while","who","whom","why","will","with","won","won't","wouldn","wouldn't","y","you","you'd","you'll","you're","you've","your","yours","yourself","yourselves","could","he'd","he'll","he's","here's","how's","i'd","i'll","i'm","i've","let's","ought","she'd","she'll","that's","there's","they'd","they'll","they're","they've","we'd","we'll","we're","we've","what's","when's","where's","who's","why's","would","able","abst","accordance","according","accordingly","across","act","actually","added","adj","affected","affecting","affects","afterwards","ah","almost","alone","along","already","also","although","always","among","amongst","announce","another","anybody","anyhow","anymore","anyone","anything","anyway","anyways","anywhere","apparently","approximately","arent","arise","around","aside","ask","asking","auth","available","away","awfully","b","back","became","become","becomes","becoming","beforehand","begin","beginning","beginnings","begins","behind","believe","beside","besides","beyond","biol","brief","briefly","c","ca","came","cannot","can't","cause","causes","certain","certainly","co","com","come","comes","contain","containing","contains","couldnt","date","different","done","downwards","due","e","ed","edu","effect","eg","eight","eighty","either","else","elsewhere","end","ending","enough","especially","et","etc","even","ever","every","everybody","everyone","everything","everywhere","ex","except","f","far","ff","fifth","first","five","fix","followed","following","follows","former","formerly","forth","found","four","furthermore","g","gave","get","gets","getting","give","given","gives","giving","go","goes","gone","got","gotten","h","happens","hardly","hed","hence","hereafter","hereby","herein","heres","hereupon","hes","hi","hid","hither","home","howbeit","however","hundred","id","ie","im","immediate","immediately","importance","important","inc","indeed","index","information","instead","invention","inward","itd","it'll","j","k","keep","keeps","kept","kg","km","know","known","knows","l","largely","last","lately","later","latter","latterly","least","less","lest","let","lets","like","liked","likely","line","little","'ll","look","looking","looks","ltd","made","mainly","make","makes","many","may","maybe","mean","means","meantime","meanwhile","merely","mg","might","million","miss","ml","moreover","mostly","mr","mrs","much","mug","must","n","na","name","namely","nay","nd","near","nearly","necessarily","necessary","need","needs","neither","never","nevertheless","new","next","nine","ninety","nobody","non","none","nonetheless","noone","normally","nos","noted","nothing","nowhere","obtain","obtained","obviously","often","oh","ok","okay","old","omitted","one","ones","onto","ord","others","otherwise","outside","overall","owing","p","page","pages","part","particular","particularly","past","per","perhaps","placed","please","plus","poorly","possible","possibly","potentially","pp","predominantly","present","previously","primarily","probably","promptly","proud","provides","put","q","que","quickly","quite","qv","r","ran","rather","rd","readily","really","recent","recently","ref","refs","regarding","regardless","regards","related","relatively","research","respectively","resulted","resulting","results","right","run","said","saw","say","saying","says","sec","section","see","seeing","seem","seemed","seeming","seems","seen","self","selves","sent","seven","several","shall","shed","shes","show","showed","shown","showns","shows","significant","significantly","similar","similarly","since","six","slightly","somebody","somehow","someone","somethan","something","sometime","sometimes","somewhat","somewhere","soon","sorry","specifically","specified","specify","specifying","still","stop","strongly","sub","substantially","successfully","sufficiently","suggest","sup","sure","take","taken","taking","tell","tends","th","thank","thanks","thanx","thats","that've","thence","thereafter","thereby","thered","therefore","therein","there'll","thereof","therere","theres","thereto","thereupon","there've","theyd","theyre","think","thou","though","thoughh","thousand","throug","throughout","thru","thus","til","tip","together","took","toward","towards","tried","tries","truly","try","trying","ts","twice","two","u","un","unfortunately","unless","unlike","unlikely","unto","upon","ups","us","use","used","useful","usefully","usefulness","uses","using","usually","v","value","various","'ve","via","viz","vol","vols","vs","w","want","wants","wasnt","way","wed","welcome","went","werent","whatever","what'll","whats","whence","whenever","whereafter","whereas","whereby","wherein","wheres","whereupon","wherever","whether","whim","whither","whod","whoever","whole","who'll","whomever","whos","whose","widely","willing","wish","within","without","wont","words","world","wouldnt","www","x","yes","yet","youd","youre","z","zero","a's","ain't","allow","allows","apart","appear","appreciate","appropriate","associated","best","better","c'mon","c's","cant","changes","clearly","concerning","consequently","consider","considering","corresponding","course","currently","definitely","described","despite","entirely","exactly","example","going","greetings","hello","help","hopefully","ignored","inasmuch","indicate","indicated","indicates","inner","insofar","it'd","keep","keeps","novel","presumably","reasonably","second","secondly","sensible","serious","seriously","sure","t's","third","thorough","thoroughly","three","well","wonder"]

remove_words.extend(stopwords.words('english'))
remove_words.extend(punctuation_signs)
remove_words.extend(custom_stop_words)

j_a_graph_df
j_a_graph_df_filtered = j_a_graph_df[~j_a_graph_df.word1.isin(remove_words)]
j_a_graph_df_filtered = j_a_graph_df_filtered[~j_a_graph_df_filtered.word2.isin(remove_words)]
j_a_graph_df_filtered_n = j_a_graph_df_filtered.head(35)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bogda\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# %pip install networkx
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: networkx in c:\python310\lib\site-packages (2.8)

# %%
import networkx as nx

# Create our Graph object
G = nx.from_pandas_edgelist(df=j_a_graph_df_filtered_n, source='word1', target='word2', edge_attr='n')

# %%
import matplotlib.pyplot as plt

# Time to draw it 
nx.draw(G, pos=nx.spring_layout(G, k=1.45, iterations=220), node_size=400, font_size=10, node_color='r', edge_color='r', with_labels=True)

plt.show()
# plt.savefig('plotgraph.png', dpi=300, bbox_inches='tight') # can also save it to file

# %%
# We could also create a directed graph, thus knowing which of the 2 words comes second in the relationship.

G_directed = nx.from_pandas_edgelist(df=j_a_graph_df_filtered_n, source='word1', target='word2', edge_attr='n', create_using=nx.DiGraph())

nx.draw(G_directed, pos=nx.spring_layout(G, k=1.45, iterations=220), node_size=400, font_size=10, node_color='r', edge_color='r', with_labels=True)
plt.savefig('plotgraph_dir.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# We can come up with many different graphs. We can make graphs out of the most common bigrams (of a book/set of books), from a chapter of a book, from an entire book, from a collection of books etc.

# %% [markdown]
# # Exercise 5
#
# Draw an undirected graph for the dataframe you've come up with for Exercise 4.
#
# You can play around with the drawing parameters if you'd like to better clusterize the data - for more details you can check https://networkx.org/documentation/stable/reference/drawing.html#module-networkx.drawing.layout

# %%
dfs
# Out:
#                   book                    2grams        word1         word2
# 0            Astrology                reiner ruf       reiner           ruf
# 3            Astrology                   and the          and           the
# 4            Astrology                the online          the        online
# 5            Astrology        online distributed       online   distributed
# 6            Astrology  distributed proofreading  distributed  proofreading
# ...                ...                       ...          ...           ...
# 37119  Fortune Telling                    526 w.          526            w.
# 37120  Fortune Telling                     w. 26           w.            26
# 37121  Fortune Telling                    26 st.           26           st.
# 37122  Fortune Telling                   st. new          st.           new
# 37123  Fortune Telling                  new york          new          york
#
# [184126 rows x 4 columns]

# %%
graph_dfs = count(dfs, _['2grams'], _.word1, _.word2, sort=True).drop(columns=['2grams'])
graph_dfs
# Out:
#           word1  word2     n
# 0            of    the  2973
# 1            in    the  1774
# 2            to    the  1030
# 3            it     is   715
# 4           and    the   617
# ...         ...    ...   ...
# 82960   growing    off     1
# 82961   growing    son     1
# 82962   growing     up     1
# 82963  growling   bear     1
# 82964    keller  calls     1
#
# [82965 rows x 3 columns]

# %%
G_directed = nx.from_pandas_edgelist(df=graph_dfs, source='word1', target='word2', edge_attr='n', create_using=nx.DiGraph())

nx.draw(G, pos=nx.spring_layout(G, k=1.45, iterations=220), node_size=400, font_size=10, node_color='r', edge_color='r', with_labels=True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Python310\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, margins)
#     453     try:
# --> 454         xy = np.asarray([pos[v] for v in nodelist])
#     455     except KeyError as err:
#
# C:\Python310\lib\site-packages\networkx\drawing\nx_pylab.py in <listcomp>(.0)
#     453     try:
# --> 454         xy = np.asarray([pos[v] for v in nodelist])
#     455     except KeyError as err:
#
# KeyError: 'of'
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11788/829636760.py in <module>
#       1 G_directed = nx.from_pandas_edgelist(df=graph_dfs, source='word1', target='word2', edge_attr='n', create_using=nx.DiGraph())
#       2
# ----> 3 nx.draw(G_directed, pos=nx.spring_layout(G, k=1.45, iterations=220), node_size=400, font_size=10, node_color='r', edge_color='r', with_labels=True)
#       4
#       5 plt.show()
#
# C:\Python310\lib\site-packages\networkx\drawing\nx_pylab.py in draw(G, pos, ax, **kwds)
#     118         kwds["with_labels"] = "labels" in kwds
#     119
# --> 120     draw_networkx(G, pos=pos, ax=ax, **kwds)
#     121     ax.set_axis_off()
#     122     plt.draw_if_interactive()
#
# C:\Python310\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     331         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     332
# --> 333     draw_networkx_nodes(G, pos, **node_kwds)
#     334     draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     335     if with_labels:
#
# C:\Python310\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, margins)
#     454         xy = np.asarray([pos[v] for v in nodelist])
#     455     except KeyError as err:
# --> 456         raise nx.NetworkXError(f"Node {err} has no position.") from err
#     457
#     458     if isinstance(alpha, Iterable):
#
# NetworkXError: Node 'of' has no position.
